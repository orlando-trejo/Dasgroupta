# %% [markdown]
# # Notebook to analyze UV-vis data

# %%
# Import libraries
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import os

# %%
# Import data
data = pd.read_excel('./UV_Vis/Pvsk_19Nov2018.xlsx', sheet_name='Sheet1')
columns = data.columns
data["Energy"] = (4.135667516E-15)*(299792458)/(data[columns[0]]*1E-9)
columns = data.columns
data.head()
# Out:
#    Wavelength nm. Blank_glass_135958 Pvsk_1_5hr_140357  Pvsk_1_5hr_140531  \
# 0           300.0            173.515              2.76              2.709
# 1           300.5            170.039             2.752              2.711
# 2           301.0            165.471             2.743              2.719
# 3           301.5             159.67             2.728              2.715
# 4           302.0            154.851             2.731              2.722
#
#    Pvsk_1_5hr_140942  Blank_glass_141217  Pvsk_full_141459  Pvsk_T_141942  \
# 0              2.678             172.337             0.049          7.496
# 1              2.689             169.096             0.050          7.544
# 2              2.688             164.721             0.050          7.598
# 3              2.692             159.266             0.051          7.639
# 4              2.737             154.278             0.052          7.645
#
#    Pvsk_NT_142332  Pvsk_NT_142639  Pvsk_NT_BL_Air_144843  \
# 0           2.672           2.643                  5.210
# 1           2.677           2.665                  5.215
# 2           2.666           2.681                  5.210
# 3           2.662           2.687                  5.225
# 4           2.690           2.702                  5.196
#
#    Pvsk_Full_BL_Air_145202  Pvsk_T_BL_Air_145538  Pvsk_1_5hr_BL_Air_145918  \
# 0                    0.081                17.463                     0.252
# 1                    0.078                17.440                     0.242
# 2                    0.077                17.392                     0.238
# 3                    0.078                17.396                     0.236
# 4                    0.082                17.403                     0.241
#
#      Energy
# 0  4.132806
# 1  4.125930
# 2  4.119076
# 3  4.112245
# 4  4.105437

# %%
columns
# Out:
# Index(['Wavelength nm.', 'Blank_glass_135958', 'Pvsk_1_5hr_140357',
#        'Pvsk_1_5hr_140531', 'Pvsk_1_5hr_140942', 'Blank_glass_141217',
#        'Pvsk_full_141459', 'Pvsk_T_141942', 'Pvsk_NT_142332', 'Pvsk_NT_142639',
#        'Pvsk_NT_BL_Air_144843', 'Pvsk_Full_BL_Air_145202',
#        'Pvsk_T_BL_Air_145538', 'Pvsk_1_5hr_BL_Air_145918', 'Energy'],
#       dtype='object')

# %%
data.plot(x=columns[0], y=[columns[10], columns[11], 
                           columns[12], columns[13]])

# %%
for column in columns[10:14]:
    name = 'A_' + column
    data[name] = 100 - data[column]
columns = data.columns

# %%
data.plot(x=columns[0], y=[columns[15], columns[16], 
                           columns[17], columns[18]])

# %%
for column in [columns[10], columns[11], columns[12], columns[13]]:    
    absorbance = 100 - data[column]
    alpha = -(1/0.00000050)*np.log(data[column]/100)
    name = column + '_Tauc_direct'
    data[name] = np.power(data['Energy'], 2) * np.power(alpha, 2)
    
columns = data.columns

# %%
len(columns)
# Out:
# 23

# %%
data.plot(x='Energy', y=[columns[20], columns[22]])
plt.xlim(1.5, 1.8)
plt.ylim(0, 0.12E15)
plt.xlabel('Energy (eV)')
plt.ylabel(r'($\alpha h \nu$)$^2$(cm$^-$$^1$ev)$^2$')
plt.savefig('tauc_plots.png', dpi=300)

# %%
for column in [columns[8], columns[4], columns[9]]:    
    absorbance = 100 - data[column]
    alpha = -(1/0.00000003)*np.log(data[column]/100)
    name = column[0:8] + '_Tauc_indirect'
    data[name] = np.power(data['Energy'], 0.5) * np.power(alpha, 0.5)
    
columns = data.columns

# %%
data.plot(x='Energy', y=[columns[17], columns[18], columns[19]])

# %%
data.plot(x='Energy', y=[columns[17]])
